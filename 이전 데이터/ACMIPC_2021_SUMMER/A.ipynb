# %%
# Out:
# 888990

# %%
a = list(a)

# %%
a
# Out:
# []

# %%
len(a)
# Out:
# 0

# %%
def one_check(a , flag):
  if(len(a) == 1):
    return int(a[0])
  if(len(a) == 2 and flag ==0):
    return int(a[0:2])
  if(len(a) == 3 and flag == 0):
    return int(a[0:3])
  if(len(a) == 3 and flag == 0):
    return int(a[0:3])
  else:
    return 0
def check(a):
  if (len(a) >= 6 and int(a[0:3]) + 1 == int(a[3:6])):
    return 3
  if((len(a) >= 4 and int(a[0:2]) +1 == int(a[2:4]))  ):
    return 2
  if((len(a) >= 2 and int(a[0])+ 1 == int(a[1]))  ):
    return 1
  if (len(a) >=3 and int(a[0]) ==9 and int(a[1:3]) == 10) :
    return 1
  if (len(a) >=5 and (int(a[0:2]) == 99) and int(a[2:5]) == 100) :
    return 2
  else:
    return 0
def check_last(a , length):
  if(len(a) >= 6 and int(a[length-6 : length -3]) +1 == int(a[length-3:])):
    return int(a[length-3 :])
  elif(len(a) >=4 and int(a[length -4 : length-2]) + 1 == int(a[length-2:]) ):
    return int(a[length-2 :])
  elif(len(a) >= 2 and (int(a[length-2]) + 1 == int(a[length-1]))):
    return int(a[length-1])
  if( len(a) >= 5 and (int(a[length-5:length-3]) == 99) and int(a[length-3:]) == 100):
    return 100
  if (len(a) >=3 and int(a[length-3]) ==9 and int(a[length-2:]) == 10) :
    return 10

# %%
one_flag = 0
flag = 0 
flag = check(a)
first = 0
last = 0
length = len(a)
one_flag = one_check(a,flag)
if(one_flag != 0):
  print(one_flag , one_flag)
if(one_flag == 0):
  if(flag == 1):
    first = int(a[0])
  elif (flag == 2):
    first = int(a[0:2])
  elif (flag == 3):
    first = int(a[0:3])
  last = check_last(a, length)
  print(first , last)
# Out:
# 99100101 99100101

# %%
length
# Out:
# 1

# %%
a,d,k = map(int , input().split())
result = 0
iter = (100-d) // k +1
# Out:
# 1 50 50

# %%
for i in range (0,iter):
  result += (a + (a*d/100) + a*(d/100)*((100-d)/100))

# %%
print(result)
# Out:
# 3.5

# %%
a = input()
def one_check(a , flag , length):
  if(length == 1):
    return int(a[0])
  if(length == 2 and flag ==0):
    return int(a[0:2])
  if(length == 3 and flag == 0):
    return int(a[0:3])
  if(length == 3 and flag == 1 and int(a[2]) != int(a[1]) +1):
    return int(a[0:3])
  else:
    return 0
def check(a , length):
  if (length >= 6 and int(a[0:3]) + 1 == int(a[3:6])):
    result = 3
  if((length >= 4 and int(a[0:2]) +1 == int(a[2:4]))  ):
    result = 2
  if((length >= 2 and int(a[0])+ 1 == int(a[1]))  ):
    result = 1
  if (length >=3 and int(a[0]) ==9 and int(a[1:3]) == 10) :
    result = 1
  if (length >=5 and (int(a[0:2]) == 99) and int(a[2:5]) == 100) :
    result = 2
  else:
    result = 0
  return result
def check_last(a , length):
  if(length >= 6 and int(a[length-6 : length -3]) +1 == int(a[length-3:])):
    result = int(a[length-3 :])
  elif(length >=4 and int(a[length -4 : length-2]) + 1 == int(a[length-2:]) ):
    result = int(a[length-2 :])
  elif(length >= 2 and (int(a[length-2]) + 1 == int(a[length-1]))):
    result = int(a[length-1])
  if( length >= 5 and (int(a[length-5:length-3]) == 99) and int(a[length-3:]) == 100):
    result = 100
  if (length >=3 and int(a[length-3]) ==9 and int(a[length-2:]) == 10) :
    result = 10
  return result
one_flag = 0
flag = 0 
length = len(a)
flag = check(a ,length)
first = 0
last = 0

one_flag = one_check(a,flag , length)
if(one_flag != 0):
  print(one_flag , one_flag)
if(one_flag == 0):
  if(flag == 1):
    first = int(a[0])
  elif (flag == 2):
    first = int(a[0:2])
  elif (flag == 3):
    first = int(a[0:3])
  last = check_last(a, length)
  print(first , last)
# Out:
# 99100101
# 99 101

# %%
1if(int(a[0]) == 9):
  print("good")
# Out:
# good

# %%
len(a)
a[0:3]
# Out:
# ['9', '9', '1']
